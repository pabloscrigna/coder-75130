# %% [markdown]
# <font size="6" color="rgb(128, 128, 0)">5. Funciones II</font>

# %% [markdown]
# * Argumentos y paŕametros

# %% [markdown]
# ### Argumentos y Parámetros

# %% [markdown]
# #### Definicion

# %% [markdown]
# En la definición de la función, las variables o valores se denominan parámetros:

# %%
# definicion
# numero1 y numero2 son los parametros de la función suma

def suma(numero1, numero2):
  return numero1 + numero2

# %% [markdown]
# En la llamada se los denomina argumentos.

# %%
def suma(numero1, numero2):
  return numero1 + numero2

# %%
# llamada a la función
# nro1 y nro2 son los argumentos de la funcion suma

nro1 = 23
nro2 = 8
suma(nro1, nro2)
# Out:
# 31

# %% [markdown]
# #### Pasando valores -- Argumentos por posición

# %% [markdown]
# Cuando se envían argumentos a una función, se reciben por orden en los parámetros definidos:

# %%
def suma(numero1, numero2):
  return numero1 + numero2

# %%
# argumentos por posicion
# definicion : suma

num1 = 30
num2 = 50

resultado = suma(num1, num2)
print(resultado)
# Out:
# 80

# %%
# llamada
suma(9,10)
# Out:
# 19

# %%
suma(7,5)
# Out:
# 12

# %%
# resta
def resta(numero1, numero2):
  print(f"El primer numero es: {numero1}")
  print(f"El segundo numero es: {numero2}")
  return numero1 - numero2

# %%
resultado = resta(7, 5)
print(resultado)
# Out:
# El primer numero es: 7
# El segundo numero es: 5
# 2

# %%
resta(5, 7)

# %% [markdown]
# #### Argumentos por nombre

# %%
# suma
def suma(num1, num2):
  return num1 + num2

# %%
resultado = suma(num1=10, num2=20)
resultado
# Out:
# 30

# %%
resultado = suma(num2=10, num1=20)
resultado
# Out:
# 30

# %%
numero1 = 23
numero2 = 8
suma(num1=numero1, num2=numero2)
# Out:
# 31

# %%
# resta
def resta(num1, num2):
  return num1 - num2

# %%
resultado = resta(num1=10, num2=20)
resultado

# %% [markdown]
# #### Llamada sin argumentos

# %%
# definicion suma
def suma(numero1, numero2=0):
  resultado = numero1 + numero2
  return resultado

# %%
# llamamos a la funcion suma sin argumentos
result = suma(5,6)
result
# Out:
# 11

# %%
result = suma(numero1=5,numero2=6)
result
# Out:
# 11

# %%
result = suma(5)
result
# Out:
# 5

# %%
result = suma(6)
result
# Out:
# 6

# %%
# valores por defecto -- calculadora
# definicion

def calculadora(num1, num2, operacion="+"):
  if operacion == "+":
    return num1 + num2
  elif operacion == "-":
    return num1 - num2

# %%
# llamada
resultado = calculadora(10, 20, "-")
resultado
# Out:
# -10

# %% [markdown]
# Preguntas❓

# %% [markdown]
# #### Argumentos por Valor y Referencia

# %% [markdown]
# Si hablamos de argumentos tenemos que tener algo en cuenta:
# Cuando **enviamos información a una función** generalmente estos datos se envían por **valor**.
# Eso significa que **se crea una copia dentro de la función de los valores que enviamos en sus propias variables**.

# %%
def incrementador(num):
  num += 1
  return

numero = 50

print(f"El valor de numero antes de la funcion es: {numero}")
print("/********/")

incrementador(numero)

print("/********/")
print(f"El valor de numero despues del llamado a la funcion es: {numero}")
# Out:
# El valor de numero antes de la funcion es: 50
# /********/
# /********/
# El valor de numero despues del llamado a la funcion es: 50

# %% [markdown]
#  **Pero**, hay casos excepcionales, las colecciones, **listas, diccionarios, conjuntos**. Estos datos se envían por **referencia**.

# %% [markdown]
# Que significa que se envian por referencia?

# %% [markdown]
# Significa que, en lugar de una copia dentro de la función, **estaremos manejando el dato original**, y si lo modificamos también se verá reflejado en el exterior, es decir, en el conjunto original y no en una copia en la función. Esto debido a que hacen referencia a la variable externa, algo así como un acceso directo.

# %%
lista1 = [0, 1, 2, 3, 4, 5, 6, 7]


def agregar_dato(lista, dato):
  if len(lista) < 10:
    lista.append(dato)
  else:
    print("La lista no tiene mas capacidad")

  return


valor = 8

print(lista1)
agregar_dato(lista1, valor)
print(lista1)
# Out:
# [0, 1, 2, 3, 4, 5, 6, 7]
# [0, 1, 2, 3, 4, 5, 6, 7, 8]

# %%
# Ejemplo con diccionario

datos = {
  "nombre" : "juan"
}

def cambiar_key_value(diccionario, clave, valor):
  diccionario[clave] = valor
  return

print(datos)
cambiar_key_value(datos, "dni", 34545345)
print(datos)
# Out:
# {'nombre': 'juan'}
# {'nombre': 'juan', 'dni': 34545345}

# %% [markdown]
# #### Resumen:

# %% [markdown]
# **Paso por valor**: se crea una copia local de la variable dentro de la función.
#
# Los tipos simples **se pasan por valor**: Enteros, flotantes, cadenas, lógicos…

# %% [markdown]
# **Paso por referencia**: Se maneja directamente la variable, los cambios realizados dentro de la función le afectarán también fuera.
#
# Los tipos compuestos **se pasan por referencia**: Listas, diccionarios, tuplas, conjuntos...

# %% [markdown]
# __Entonces__:
#
# ¿Es posible que de alguna forma le digamos a Python cuándo queremos pasar un argumento por referencia o por valor?

# %% [markdown]
# **Respuesta:**

# %%
# Ejemplo : Argumento valor por referencia
def incrementador(num):
  num += 1
  return num

  numero = 50

print(f"El valor de numero antes de la funcion es: {numero}")
print("/********/")

# incrementador(numero)

numero = incrementador(numero)

print("/********/")
print(f"El valor de numero despues de la funcion es: {numero}")
# Out:
# El valor de numero antes de la funcion es: 50
# /********/
# /********/
# El valor de numero antes de la funcion es: 51

# %%
lista1 = [0, 1, 2, 3, 4, 5, 6, 7]


def agregar_dato(lista, dato):
  lista = lista.copy()
  if len(lista) < 10:
    lista.append(dato)
  else:
    print("La lista no tiene mas capacidad")

  return lista


valor = 8

print(lista1)
lista_nueva = agregar_dato(lista1, valor)
print(lista1)
print(lista_nueva)
# Out:
# [0, 1, 2, 3, 4, 5, 6, 7]
# [0, 1, 2, 3, 4, 5, 6, 7]
# [0, 1, 2, 3, 4, 5, 6, 7, 8]

# %% [markdown]
# Preguntas❓

# %% [markdown]
# #### Argumentos indeterminados

# %% [markdown]
# #### *args

# %% [markdown]
# Permiten definir funciones cuyo número de argumentos es variable. Es decir, podemos definir funciones genéricas que no aceptan un número determinado de parámetros, sino que se “adaptan” al número de argumentos con los que son llamados.

# %%
#ejemplo args
# definicion
def suma(*args):
  resultado = 0
  for numero in args:
    resultado += numero
  return resultado

# %%
# ejemplo 1
resultado = suma(1, 6, 7, 8, 9)
resultado
# Out:
# 31

# %%
# ejemplo2
resultado = suma(1, 6, 7, 8, 9)
resultado
# Out:
# 31

# %% [markdown]
# #### *kwargs

# %% [markdown]
# Los **kwargs nos permiten dar un nombre a cada argumento de entrada, pudiendo acceder a ellos dentro de la función a través de un diccionario.

# %%
# definicion kwargs
def suma(**kwargs):
  resultado = 0
  for numero in kwargs.values():
    resultado += numero
  return resultado

# %%
# ejemplo
resulatdo = suma(num1=10, num2=20, num3=30)
resulatdo
# Out:
# 60

# %% [markdown]
# __Nota__: args y kwargs se pueden llaman asi por convencion, pero podrian tener otro nombre

# %% [markdown]
# ### Multiples return

# %%
# ejemplo division
def division(dividendo, divisor):
  if divisor == 0:
    return "No se puede dividir por cero"
  else:
    return dividendo / divisor

# %%
nro1 = 10
nro2 = 2
print(division(nro1, nro2))
# Out:
# 5.0

# %%
4/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-62-221068dc2815> in <cell line: 1>()
# ----> 1 4/0
#
# ZeroDivisionError: division by zero

# %% [markdown]
# Preguntas❓

# %% [markdown]
# ### Funciones recursivas

# %% [markdown]
# **Recursividad**
#
# Cuando una función se llama a sí misma, tenemos una función recursiva con un comportamiento muy similar al de una sentencia iterativa (if, while, etc.) pero debemos encargarnos de planificar el momento en que dejan de llamarse a sí mismas o tendremos una función recursiva infinita.

# %%
# Funcion recursiva con retorno

# factorial 1 (1!) = 1
# factorial 2 (2!) = 2 * 1
# factorial 3 (3!) = 3 * 2 * 1
# factorial 4 (4!) = 4 * 3 * 2 * 1
# factorial 5 (5!) = 5 * 4 * 3 * 2 * 1

def factorial(numero):

  if numero == 1:
    return numero

  numero = numero * factorial(numero - 1)

  return numero

# %%
24 * 5
# Out:
# 120

# %%
print(factorial(5))
# Out:
# 120

# %% [markdown]
# Preguntas❓

# %% [markdown]
# ### Funciones integradas

# %% [markdown]
# __Built-in functions__: Son funciones que estan incorporadas en el lenguaje.
#
# Para mas informacion pueden acceder a la [documentación](https://docs.python.org/es/3/library/functions.html)

# %%
# int
int(2.5)

# %%
# str
str(34)

# %%
# round
round(3.45)

# %%
# help
help()

# %%
lista = [0,10,30,40]

for indice, valor in enumerate(lista):
  print(f"indice: {indice} - valor: {valor}")

# %% [markdown]
# ### Typehints

# %% [markdown]
# * Disponible en python desde la version 3.5
# * No es obligatorio!!!
# * Especificar los tipo de dato de los argumentos de una funcion
# * Especificar el tipo de dato que retorna una funcion
# * Chequeo estatico - no en runtime

# %%
def factorial(numero: int)-> int:

  if numero == 1:
    return numero

  numero = numero * factorial(numero - 1)

  return numero

# %%
factorial(3)

# %%
age: int = 25
name: str = "Alice"
height: float = 5.9
is_student: bool = True

# %%
age
# Out:
# 25

# %%
age = "2"

# %%
age
# Out:
# '2'

# %%
def saludar(nombre: str)->str:
  return f""

# %%
def add(a: int, b: int) -> int:
    return a + b

# %%
from typing import List

def total_marks(marks: List[int]) -> int:
    return sum(marks)

# %%
from typing import Tuple

def get_student() -> Tuple[str, int]:
    return "Alice", 25

# %%
from typing import Dict

def count_fruits(fruit_basket: Dict[str, int]) -> int:
    return sum(fruit_basket.values())

# %%
from typing import Tuple

def get_student() -> Tuple[str, int]:
    return "Alice", 25

# %%
from typing import Optional

def find_user(user_id: int) -> Optional[str]:
    if user_id == 1:
        return "Alice"
    else:
        return None

# %%
como seria un optional como parametro???

def greet(name: Optional[str] = None) -> str:

# %% [markdown]
# ### Docstrings

# %% [markdown]
# Documentar funciones

# %%
def factorial(numero: int)-> int:
  """
    Esta funcion calcula el factorial del numero que se le pasa
    como argumento.
  """

  if numero == 1:
    return numero

  numero = numero * factorial(numero - 1)

  return numero

# %%
help(factorial)
# Out:
# Help on function factorial in module __main__:
#
# factorial(numero: int) -> int
#     Esta funcion calcula el factorial del numero que se le pasa
#     como argumento.

# %%
factorial(4)
# Out:
# 24

# %%
def saludar():
  print("Hola mundo")
  return

# %%
saludar()

# %%
saludo = saludar

# %%
saludo()

# %% [markdown]
# Preguntas❓

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Ejercicios!!!!

# %% [markdown]
# vamos al vscode!!!

# %%
def suma(num1: int, num2: int):
  return num1 + num2



suma(1.6,1.8)

# %% [markdown]
# ###![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
